# %% [markdown]
# ### Testing training models

# %%
import DePa

fn = 'IMG_0392_inputs'
image_path = '/home/dietrich/Testing/DECA/DECA/TestSamples/examples/IMG_0392_inputs.jpg'
results_path = '/home/dietrich/Testing/DECA/DECA/training_results/coarse_test'
pretrained_modelpath = '/home/dietrich/Testing/DECA/DECA/training_results/coarse/model.tar'

DePa.decode(fn, image_path, results_path, pretrained_modelpath)
# Out:
# 0
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0
# 100%|██████████| 1/1 [00:04<00:00,  4.16s/it]
# {'tex': tensor([[-3.5904e-03, -1.4931e-03, -3.3364e-03,  1.7477e-03, -1.7565e-03,
#            4.4298e-03,  1.2643e-03,  4.4278e-03, -9.5890e-04,  4.1891e-03,
#            3.1420e-03,  1.3808e-03,  3.8970e-03,  3.0488e-03, -1.4846e-03,
#            3.9463e-03,  7.9140e-05,  7.5319e-04,  2.9673e-03,  2.1817e-03,
#            1.8352e-03,  4.8510e-03, -2.4297e-03,  1.2084e-03, -1.0647e-03,
#            3.9331e-03, -4.7623e-03, -3.2863e-03,  8.3770e-03, -3.9128e-03,
#            1.2691e-03, -4.3348e-03,  4.5476e-03, -7.8147e-04,  7.8549e-03,
#            6.8560e-04, -1.1067e-03,  2.9333e-03, -4.4397e-03,  2.8399e-03,
#           -4.5541e-03, -3.6872e-03, -1.7173e-03,  4.5078e-04,  3.0446e-03,
#            1.5347e-03, -4.8932e-03, -6.1675e-04,  6.0697e-03, -2.8175e-03]],
#         device='cuda:0'),
#  'exp': tensor([[ 9.0717e-03, -6.0819e-02,  3.5201e-02,  2.2031e-02, -4.7447e-02,
# ...
